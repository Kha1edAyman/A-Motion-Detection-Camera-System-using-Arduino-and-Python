# %%
import pandas as pd
data=pd.read_csv('https://raw.githubusercontent.com/Rajvardhan180/House_Price_Prediction/main/data/Housing.csv')
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
premium_ = data[(data['guestroom'] == "yes") &( data["area"] >3000 )& (data['airconditioning'] == 'yes')]

# %%
premium_
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 4    11410000  7420         4          1        2      yes       yes      yes
# 8     9870000  8100         4          1        2      yes       yes      yes
# 9     9800000  5750         3          2        4      yes       yes       no
# 16    9100000  6600         4          2        2      yes       yes      yes
# 18    8890000  4600         3          2        2      yes       yes       no
# 21    8680000  7155         3          2        1      yes       yes      yes
# 22    8645000  8050         3          1        1      yes       yes      yes
# 23    8645000  4560         3          2        2      yes       yes      yes
# 25    8540000  6540         4          2        2      yes       yes      yes
# 26    8463000  6000         3          2        4      yes       yes      yes
# 34    8120000  6840         5          1        2      yes       yes      yes
# ...

# %%
result1 = premium_.groupby('furnishingstatus')[['price', 'bedrooms']].mean()

# %%
result1
# Out:
#                          price  bedrooms
# furnishingstatus
# furnished         7.039455e+06  3.545455
# semi-furnished    6.170231e+06  3.000000
# unfurnished       7.185938e+06  3.125000

# %%
data['energy_load'] = ((data['area'] *0.5) + (data['bedrooms'] *0.5))+(data['bathrooms'] *0.5)

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
filterd.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 378  3640000  2275         3          1        3      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 378             yes             yes        0      yes   semi-furnished
#
#      energy_load
# 378       1139.5

# %%
filterd.count()
# Out:
# price               1
# area                1
# bedrooms            1
# bathrooms           1
# stories             1
# mainroad            1
# guestroom           1
# basement            1
# hotwaterheating     1
# airconditioning     1
# parking             1
# prefarea            1
# furnishingstatus    1
# energy_load         1
# dtype: int64

# %%
filterd.groupby('furnishingstatus')[['energy_load' , 'price']] .mean()
# Out:
#                   energy_load      price
# furnishingstatus
# semi-furnished         1139.5  3640000.0
